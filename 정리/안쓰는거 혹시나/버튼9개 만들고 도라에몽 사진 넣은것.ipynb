# %%
from tkinter import *
from PIL import ImageTk


root = Tk()

# 이미지 객체 생성
image1 = ImageTk.PhotoImage(file="D:/python/skin/output/bt001.jpg")
image2 = ImageTk.PhotoImage(file="D:/python/skin/output/bt002.jpg")
image3 = ImageTk.PhotoImage(file="D:/python/skin/output/bt003.jpg")
image4 = ImageTk.PhotoImage(file="D:/python/skin/output/bt004.jpg")
image5 = ImageTk.PhotoImage(file="D:/python/skin/output/bt005.jpg")
image6 = ImageTk.PhotoImage(file="D:/python/skin/output/bt006.jpg")
image7 = ImageTk.PhotoImage(file="D:/python/skin/output/bt007.jpg")
image8 = ImageTk.PhotoImage(file="D:/python/skin/output/bt008.jpg")
image9 = ImageTk.PhotoImage(file="D:/python/skin/output/bt009.jpg")


def create_button(image, command, *args, **kwargs):
    button = Button(root, image=image, command=command, *args, **kwargs)
    return button

# 버튼 명령 함수
def command_1():
    print("Button 1")

def command_2():
    print("Button 2")

def command_3():
    print("Button 3")

def command_4():
    print("Button 4")

def command_5():
    print("Button 5")

def command_6():
    print("Button 6")

def command_7():
    print("Button 7")

def command_8():
    print("Button 8")

def command_9():
    print("Button 9")


upper_color = "white" 
frame_btcolor = '#FEE73B'
button_bg =  '#2196f3' # 파란색
button_fg = 'white'
cen_button_bg = 'white'
cen_button_fg = "black"
btsize = 30

myfont = "Arial"

# 버튼 생성 및 배치
button1 = create_button(image1, command_1, text="Button 1", compound="center", fg=button_fg, font=(myfont,btsize, "bold"))
button1.grid(row=0, column=0)

button2 = create_button(image2, command_2, text="Button 1", compound="center", fg=button_fg, font=(myfont,btsize, "bold"))
button2.grid(row=0, column=1)

button3 = create_button(image3, command_3, text="Button 1", compound="center", fg=button_fg, font=(myfont,btsize, "bold"))
button3.grid(row=0, column=2)

button4 = create_button(image4, command_4, text="Button 1", compound="center", fg=button_fg, font=(myfont,btsize, "bold"))
button4.grid(row=1, column=0)

button5 = create_button(image5, command_5, text="Button 1", compound="center", fg=button_fg, font=(myfont,btsize, "bold"))
button5.grid(row=1, column=1)

button6 = create_button(image6, command_6, text="Button 1", compound="center", fg=button_fg, font=(myfont,btsize, "bold"))
button6.grid(row=1, column=2)

button7 = create_button(image7, command_7, text="Button 1", compound="center", fg=button_fg, font=(myfont,btsize, "bold"))
button7.grid(row=2, column=0)

button8 = create_button(image8, command_8, text="Button 1", compound="center", fg=button_fg, font=(myfont,btsize, "bold"))
button8.grid(row=2, column=1)

button9 = create_button(image9, command_9, text="Button 1", compound="center", fg=button_fg, font=(myfont,btsize, "bold"))
button9.grid(row=2, column=2)

root.mainloop()
# Out:
# Button 9
# Button 8
# Button 7
# Button 4
# Button 5
# Button 6
# Button 1
# Button 2
# Button 3
# Button 2
# Button 5
