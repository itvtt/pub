# %%
import tkinter as tk

# 윈도우 생성
window = tk.Tk()

# label = tk.Label(window, text="Hello, world!", font=(myfont,btsize, "bold"))


# 윈도우 크기 설정
window.configure(bg="white")  # (bg="#00A0E9")
window_width = 760
window_height = 800
window.title("Doraemon Pocket")
screen_width = window.winfo_screenwidth()
screen_height = window.winfo_screenheight()
x_coordinate = (screen_width/2) - (window_width/2)
y_coordinate = (screen_height/2) - (window_height/2)
window.geometry('%dx%d+%d+%d' % (window_width, window_height, x_coordinate, y_coordinate))



##################여기서부터 함수##################

    
def 함수():
    print("Hi")

##################여기까지이 함수##################

# 색지정
# upper_color = "#00A0E9" #"#F0F0F0"
# frame_btcolor = "#FFFFFF" #"#FEE73B"
# button_bg = "#FEE73B" #"#FFFFFF"
# button_fg = "#E1002A" # "#E1002A"


upper_color = "white" 
frame_btcolor = '#FEE73B'
button_bg =  '#2196f3' # 파란색
button_fg = 'white'
cen_button_bg = 'white'
cen_button_fg = "black"

myfont = "Arial"

#\n버튼크기
px = 5
py = 5
btw = 10
bth = 5
btsize = 20


# 상위 프레임 생성
main_frame = tk.Frame(window, padx=px, pady=py, bg=upper_color)
main_frame.pack(side="left", anchor="nw")

# 프레임1 생성
frame1 = tk.Frame(window, padx=px, pady=py, bg=upper_color) # padx와 pady를 설정하여 프레임 내부에 여백을 줌
frame1.pack(side="left", anchor="nw")
# 프레임1 \n버튼 생성
button1 = tk.Button(frame1, text="프레임1\n버튼", width=btw, height=bth , bg=button_bg, fg=button_fg, font=(myfont,btsize, "bold") ,command=함수)
button1.pack() # pack() 메서드로 \n버튼을 배치함

# 프레임2 생성
frame2 = tk.Frame(window, padx=px, pady=py, bg=upper_color) # padx와 pady를 설정하여 프레임 내부에 여백을 줌
frame2.pack(side="left", anchor="nw")
# 프레임2 \n버튼 생성
button2 = tk.Button(frame2, text="프레임2 \n버튼", width=btw, height=bth , bg=cen_button_bg, fg=cen_button_fg, font=(myfont,btsize, "bold") ,command=함수)
button2.pack() # pack() 메서드로 \n버튼을 배치함

# 프레임3 생성
frame3 = tk.Frame(window, padx=px, pady=py, bg=upper_color) # padx와 pady를 설정하여 프레임 내부에 여백을 줌
frame3.pack(side="left", anchor="nw")
# 프레임3 \n버튼 생성
button3 = tk.Button(frame3, text="프레임3 \n버튼", width=btw, height=bth , bg=cen_button_bg, fg=cen_button_fg, font=(myfont,btsize, "bold") ,command=함수)
button3.pack() # pack() 메서드로 \n버튼을 배치함

# 프레임4 생성
frame4 = tk.Frame(window, padx=px, pady=py, bg=upper_color) # padx와 pady를 설정하여 프레임 내부에 여백을 줌
frame4.pack(side="left", anchor="nw")
# 프레임4 \n버튼 생성
button4 = tk.Button(frame4, text="프레임4 \n버튼", width=btw, height=bth , bg=button_bg, fg=button_fg, font=(myfont,btsize, "bold") ,command=함수)
button4.pack() # pack() 메서드로 \n버튼을 배치함

# 프레임5 생성
frame5 = tk.Frame(window, padx=px, pady=py, bg=upper_color) # padx와 pady를 설정하여 프레임 내부에 여백을 줌
frame5.pack(side="left", anchor="nw")
# 프레임5 \n버튼 생성
button5 = tk.Button(frame1, text="프레임5 \n버튼", width=btw, height=bth , bg=button_bg, fg=button_fg, font=(myfont,btsize, "bold") ,command=함수)
button5.pack() # pack() 메서드로 \n버튼을 배치함

# 프레임6 생성
frame6 = tk.Frame(window, padx=px, pady=py, bg=upper_color) # padx와 pady를 설정하여 프레임 내부에 여백을 줌
frame6.pack(side="left", anchor="nw")
# 프레임6 \n버튼 생성
button6 = tk.Button(frame2, text="프레임6 \n버튼", width=btw, height=bth , bg=cen_button_bg, fg=cen_button_fg, font=(myfont,btsize, "bold") ,command=함수)
button6.pack() # pack() 메서드로 \n버튼을 배치함

# 프레임7 생성
frame7 = tk.Frame(window, padx=px, pady=py, bg=upper_color) # padx와 pady를 설정하여 프레임 내부에 여백을 줌
frame7.pack(side="left", anchor="nw")
# 프레임7 \n버튼 생성
button7 = tk.Button(frame3, text="프레임7 \n버튼", width=btw, height=bth , bg=cen_button_bg, fg=cen_button_fg, font=(myfont,btsize, "bold") ,command=함수)
button7.pack() # pack() 메서드로 \n버튼을 배치함

# 프레임8 생성
frame8 = tk.Frame(window, padx=px, pady=py, bg=upper_color) # padx와 pady를 설정하여 프레임 내부에 여백을 줌
frame8.pack(side="left", anchor="nw")
# 프레임8 \n버튼 생성
button8 = tk.Button(frame4, text="프레임8 \n버튼", width=btw, height=bth , bg=button_bg, fg=button_fg, font=(myfont,btsize, "bold") ,command=함수)
button8.pack() # pack() 메서드로 \n버튼을 배치함

# 윈도우 실행
window.mainloop()
